# %% [markdown]
# #**Relatório de Desempenho | Alura Store**

# %% [markdown]
# ## **Visão geral**

# %% [markdown]
# A AluraStore é uma rede formada por 4 lojas, de propriedade do Sr. João. Nestas lojas, os clientes podem encontrar à venda 51 itens diferentes que podem ser classificados em 8 categorias de produtos:
#
# *   Móveis
# *   Eletrodomésticos
# *   Eletrônicos
# *   Brinquedos
# *   Utilidades domésticas
# *   Livros
# *   Instrumentos musicais
# *   Esporte e lazer

# %% [markdown]
# Com vendas em todo o território brasileiro, o maior número de vendas é concentrado nos estados de São Paulo, Rio de Janeiro, Minas Gerais, Paraná e Rio Grande do Sul, dentre os quais São Paulo tem liderança isolada.

# %% [markdown]
# A rede aceita 4 formas de pagamento:
#
# *   Cartão de crédito
# *   Boleto
# *   Cupom
# *   Cartão de débito
#
# sendo esta a frequência de escolha dos clientes.
#
# Em sua maioria, as compras são parceladas, de 1 a 24, com concentração de 75% em até 4 parcelas.

# %% [markdown]
# ## **Objetivo**

# %% [markdown]
# O Sr. João, proprietário da rede, tomou a decisão de vender uma das lojas, assim, capitalizando-a, para poder realizar um investimento em outro negócio.
#
# Por isso, vamos analisar o desempenho das 4 lojas da rede entre os anos de 2020 e 2023, análise que visa apoiar a decisão do Sr. João, contemplando métricas como:
#
# *   Faturamento total das lojas
# *   Categorias de produtos mais e menos vendidas
# *   Média das avaliações de clientes por loja
# *   Produtos mais e menos vendidos
# *   Frete médio de cada loja

# %% [markdown]
# ## **Material de análise**

# %% [markdown]
# Conforme citado, utilizaremos dados de vendas das 4 lojas, referente aos anos de 2020 à 2023. Quanto ao ano de 2023, os dados são parciais e referem-se ao 1º Trimestre, e serão considerados para projeções.

# %% [markdown]
# Cada linha do conjunto de dados é referente à uma venda. Cada venda possui os seguintes dados: nome do produto, categoria do produto, preço, frete, data da compra, nome do vendedor, local de compra, avaliação da compra, tipo de pagamento, número de parcelas e geolocalização (latitude e longitude).

# %% [markdown]
# ## **Análises**

# %% [markdown]
# ### **Faturamento**

# %% [markdown]
# Com uma média de faturamento de 1.467.872,70,  o maior faturamento é obtido pela Loja 1, de 1.534.509,12, seguido da loja 2, loja 3 e da loja 4, com o menor faturamento de 1.384.497,58.
#
# A diferença entre a Loja 1 e Loja 4 é de 150 mil reais, e o desempenho da loja 4 é de 90% em relação a Loja 1.

# %% [markdown]
# ![faturamento_por_loja.png](data:image/png;base64,...)

# %% [markdown]
# #### **Faturamento por ano e loja**

# %% [markdown]
# No ano de **2020**, o número médio de vendas foi 715.
#
# *   As Lojas 2 e 3 tiveram o menor número de vendas e o menor faturamento.
# *   A Loja 4 teve o maior número de vendas, no entanto,  o faturamento da Loja 1 foi maior que todas as outras lojas e obteve o maior ticket médio.

# %% [markdown]
# | Unidade | Número de vendas | Faturamento | Ticket médio
# | :---: | :---: | :---: | :---: |
# | Loja 1 | 715 | 491.911,51 | 687,99 |
# | Loja 2 | 700 | 427.288,25 | 610,41 |
# | Loja 3 | 701 | 428.943,09 | 611,90 |
# | Loja 4 | 745 | 441.129,52 | 597,12 |

# %% [markdown]
# O tícket médio é uma métrica que representa o valor médio gasto por cliente em cada compra realiza em um determinado período. Podemos entender se os esforços estão voltados para vendas mais lucrativas ou apenas para volume.

# %% [markdown]
# Em **2021**, a média de vendas foi 745, o que demonstra aumento de vendas.
#
# *   A Loja 2 teve o maior número de vendas, no entando, a Loja 3, com menor número de vendas, obteve maior faturamento e maior ticket médio.
#
# *   Entre as lojas 1, 3 e 4, o número de vendas é próximo, o menor faturamento foi da Loja 4, denotando-se o aumento do ticket médio de 2020 para 2021.
#
# *   Loja 1 e Loja 2 tiveram o mesmo tícket médio.
#
# *   Estabilidade de vendas da Loja 4

# %% [markdown]
# | Unidade | Número de vendas | Faturamento | Ticket médio
# | :---: | :---: | :---: | :---: |
# | Loja 1 | 739 | 482.829,91 | 653,36 |
# | Loja 2 | 759 | 482.829,91 | 636,14 |
# | Loja 3 | 740 | 483.938,91 | 653,97 |
# | Loja 4 | 744 | 463.763,27 | 632,34 |

# %% [markdown]
# O ano de **2022**, com uma média de vendas de 724, marca queda geral das vendas em relação à 2021, mas recuperação em relação à 2020.
#
# *   A Loja 1, com número de vendas acima da média, teve faturamento mais baixo que a loja 2, com número de vendas abaixo da média. Denota-se também o baixo valor de tícket médio, acima apenas da Loja 4.
#
# *   Loja 3 e 4 tiveram os melhores faturamento.
#
#
# *   Loja 4 teve menor faturamento e o menor tícket médio - em declinio em relação à 2021.

# %% [markdown]
# | Unidade | Número de vendas | Faturamento | Ticket médio
# | :---: | :---: | :---: | :---: |
# | Loja 1 | 739 | 422.086,24 | 571,16 |
# | Loja 2 | 708 | 477.635,56 | 674,63 |
# | Loja 3 | 740 | 467.250,70 | 631,42 |
# | Loja 4 | 712 | 402.961,23 | 565,96 |

# %% [markdown]
# O primeiro trimestre de **2023** aponta que a loja 4 teve o menor número de vendas acompanhado do menor faturamento.
#
# *   Loja 3 teve o pior ticket médio, no entanto, com o maior número de vendas, obteve melhor faturamento que a Loja 4.
# *   O tícket médio da Loja 4 se mantém em declínio.

# %% [markdown]
# | Unidade | Número de vendas | Faturamento | Ticket médio
# | :---: | :---: | :---: | :---: |
# | Loja 1 | 192 | 137.681,46 | 717,09 |
# | Loja 2 | 192 | 115.246,36 | 600,24 |
# | Loja 3 | 178 | 83.892,33 | 471,31 |
# | Loja 4 | 157 | 76.643,33 | 488,18 |

# %% [markdown]
# ![faturamento_anos.png](data:image/png;base64,...)

# %% [markdown]
# A projeção do faturamento de 2023 é que todas as lojas tenham aumento, destacando-se positivamente as lojas 1 e 2, com performances menor destacadas as lojas 3 e 4.

# %% [markdown]
# ![vendas_loja.png](data:image/png;base64,...)

# %% [markdown]
# A projeção de vendas de 2023 é de aumento para as lojas 1 e 2. As lojas 3 e 4, com queda nas vendas sendo a Loja 4 a de pior projeção, se distanciando da média de vendas.
#
# Enquanto as demais lojas apresentam movimentos de crescimento, queda e estabilidade, a Loja 4 tem experimentado queda contínua e acentuada.

# %% [markdown]
# ![ticket.png](data:image/png;base64,...)

# %% [markdown]
# Quanto ao tícket médio, a Loja 1 tem o melhor tícket médio - que está em crescimento, as demais lojas apresentam queda.
#
# As piores quedas são da Loja 3 e Loja 4.

# %% [markdown]
# ###**Vendas por categoria**

# %% [markdown]
# Dentre as 4 lojas, as categorias de produtos mais vendidas são:
#
# 1.   Móveis
# 2.   Eletrônicos
# 3.   Brinquedos

# %% [markdown]
# ![volume_vendas.png](data:image/png;base64,...)

# %% [markdown]
# Durante a pandemia, a busca por móveis, eletrônicos e brinquedos aumentou significativamente no Brasil, impulsionada pela necessidade de adaptação ao isolamento social e à rotina de trabalho e estudo em casa.
#
# O comércio eletrônico foi o principal canal para essas compras, registrando um crescimento expressivo no período.

# %% [markdown]
# Em conjunto, as três categorias agrupadas impactaram próximo à 60% do faturamento, com cerca de 50% das vendas.

# %% [markdown]
# | Unidade | Categorias mais vendidas | % Faturamento | % Vendas
# | :---: | :---: | :---: | :---: |
# | Loja 1 | 846.831,12 | 55,19 | 52,44 |
# | Loja 2 | 804.270,60 | 54,03 | 49,89 |
# | Loja 3 | 841.664,68 | 57,49 | 53,62 |
# | Loja 4 | 829.688,18 | 59,93 | 53,82 |

# %% [markdown]
# ![caegorias.png](data:image/png;base64,...)![categorias_l2.png](data:image/png;base64,...)![categorias_l3.png](data:image/png;base64,...)![categorias_l4.png](data:image/png;base64,...)

# %% [markdown]
# ###**Avaliação da Compra**

# %% [markdown]
# A média de avaliação das notas é de 4,02, com a primeira posição para a Loja 3 e a última posição para a Loja 1.

# %% [markdown]
# | Unidade | Avaliação média |
# | :---: | :---: |
# | Loja 1 | 3,98 |
# | Loja 2 | 4,04 |
# | Loja 3 | 4,05 |
# | Loja 4 | 4,00 |

# %% [markdown]
# Pelo gráfico de distribuição, denota-se que o maior número de notas estão acima da média geral, para todas as lojas.

# %% [markdown]
# ![notas_medias.png](data:image/png;base64,...)

# %% [markdown]
# ### **Itens e mais e menos vendidos**

# %% [markdown]
# Considerando o número de itens vendidos pelas lojas, tomamos como amostra os 10 itens mais vendidos e os 10 itens menos vendidos, perfazendo cada grupo cerca de 20% do número de itens.

# %% [markdown]
# As categorias mais vendidas, como outrora mencionado, são móveis, eletrônicos e brinquedos.
#
# As categorias menos vendidas são livros, instrumentos musicais e utilidades domésticas.

# %% [markdown]
# *Itens mais vendidos*

# %% [markdown]
# | Loja 1 | Loja 2 | Loja 3 | Loja 4
# | :---: | :---: | :---: | :---: |
# | Microondas | Iniciando em programação | Kit banquetas | Cama box |
# | TV Led UHD 4K| Miroondas | Mesa de jantar | Faqueiro |
# | Guarda roupas | Bateria | Cama king | Dashboards com Power BI |
# | Secadora de roupas  | Violão | Jogo de panelas | Cama king |
# | Cômoda | Pandeiro | Cômoda | Carrinho controle remoto |
# | Blocos de montar | Secadora de roupas | Smart TV | Mesa de jantar |
# | Bola de basquete | Celular Plus X42 | Fogão | Cômoda |
# | Bicicleta | Blocos de montar | Corda de pular | Smart TV |
# | Copo térmico | Guarda roupas | Modelagem preditiva | Blocos de montar|
# | Geladeira | Jogo de panelas | Carrinho de controle remoto | Pandeiro |

# %% [markdown]
# Dentre os itens mais vendidos, destacamos pontos de atenção quanto à Loja 2, que entre os mais vendidos possui livros e instrumentos musicais. A Loja 4, itens de utilidade domésticas e livros.

# %% [markdown]
# *Itens menos vendidos*

# %% [markdown]
# | Loja 1 | Loja 2 | Loja 3 | Loja 4
# | :---: | :---: | :---: | :---: |
# | Celular ABXY | Jogo de tabuleiro | Blocos de montar | Guitarra |
# | Headset | Impressora | Microondas | Guarda roupas |
# | Panela de pressão | Mesa de jantar | Mochila | Violão |
# | Pandeiro  | Poltrona | Jogo de copos | Ciência de dados com python |
# | Ciência de dados com python | Fone de ouvido | Guitarra | Geladeira |
# | Mochila | Assistente virtual | Copo térmico | Lavadora de roupas |
# | Corda de pular | Faqueiro | Assistente virtual | Smartwatch |
# | Dinossauro Rex | Smart TV | Headset | Xadrez de madeira |
# | Mesa de jantar | Celular ABXY | Boneca bebê | Celular ABXY|
# | Boneca bebê | Dinossauro Rex | Faqueiro | Cadeira de escritório |

# %% [markdown]
# ### **Frete médio**

# %% [markdown]
# Consoante ao frete, que é pago pelo cliente, o valor alto de frete corresponde à vendas mais distantes e produtos mais caros.
#
# O frete gratuito é uma estratégia para aumentar o ticket médio, incentivando os consumidores a adicionarem mais itens ao carinho para atingir o valor mínimo necessário.
#
# No entanto, o frete gratuito pode gerar dependência e diminuir vendas, e o cliente aguardar nova promoção com frete grátis.

# %% [markdown]
# | Unidade | Frete médio | Frete zero | % Frete zero
# | :---: | :---: | :---: | :---: |
# | Loja 1 | 34,69 | 209 | 8,86 |
# | Loja 2 | 33,62 | 214 | 9,07 |
# | Loja 3 | 33,07 | 208 | 8,82 |
# | Loja 4 | 31,28 | 196 | 8,31 |

# %% [markdown]
# ## **Conclusão**

# %% [markdown]
# Feitas as análises, com base nos dados fornecidos, considerando o menor faturamento total, o declínio acentuado no número de vendas, a queda contínua do valor de tícket médio, que a estratégia de frete grátis não tem aumentado o tícket médio, recomendo que a Loja 4 seja vendida.
